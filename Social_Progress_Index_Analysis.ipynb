# %% [markdown]
# <a href="https://colab.research.google.com/github/IrfanPavel/Social-Progress-Index-Analysis/blob/main/Social_Progress_Index_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The Social Progress Index (SPI) is a measure that gives an understanding of social progress globally. It helps in understanding how much countries care about the overall development of the citizens**

# %% [markdown]
# Social Progress Index Analysis
#
# The Social Progress Index score is calculated by analyzing the overall development of the citizens of a country. Below are all the factors considered for calculating the Social Progress Score:
#
# Basic human needs
#
# Wellbeing
#
# Opportunities
#
# Nutritional and basic medical care
#
# Water and sanitation
#
# Shelter
#
# Personal Safety
#
# Access to basic knowledge
#
# Access to information and communication
#
# Health and wellness
#
# Environment quality
#
# Personal rights
#
# Personal freedom and choice
#
# Inclusiveness
#
# Access to advanced education
#
# So these are the primary factors considered while calculating the SPI score of a country.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import iplot

data = pd.read_csv("/content/spi.csv")
print(data.head())

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   spi_rank                 168 non-null    float64
#  1   country                  169 non-null    object
#  2   spi_score                169 non-null    float64
#  3   basic_human_needs        169 non-null    float64
#  4   wellbeing                169 non-null    float64
#  5   opportunity              169 non-null    float64
#  6   basic_nutri_med_care     169 non-null    float64
#  7   water_sanitation         169 non-null    float64
#  8   shelter                  169 non-null    float64
#  9   personal_safety          169 non-null    float64
#  10  access_basic_knowledge   169 non-null    float64
#  11  access_info_comm         169 non-null    float64
#  12  health_wellness          169 non-null    float64
#  13  env_quality              169 non-null    float64
#  14  personal_rights          169 non-null    float64
#  15  personal_freedom_choice  169 non-null    float64
#  16  inclusiveness            169 non-null    float64
#  17  access_adv_edu           169 non-null    float64
# dtypes: float64(17), object(1)
# memory usage: 23.9+ KB
# None

# %% [markdown]
# # **Now let’s have a look at the average, highest, and minimum of the SPI score so that we can categorize scores as High and low:**

# %%
print("Highet SPI Score : ", data["spi_score"].max())
print("Lowest SPI Score : ", data["spi_score"].min())
print("Average SPI Score: ", data["spi_score"].mean())
# Out:
# Highet SPI Score :  92.63
# Lowest SPI Score :  32.5
# Average SPI Score:  67.43313609467457

# %% [markdown]
# # **As 67 is the average SPI score and 92 is the highest, we can consider 85 as the qualifying score for a high SPI score.**

# %% [markdown]
# # **So let’s analyze some data about the countries with high SPI scores.**

# %% [markdown]
# # **Let’s start with a look at the countries with better basic human needs facilities:**

# %%
fig = px.scatter(data.query("spi_score >= 85"), 
                 x="basic_human_needs", 
                 y="spi_score",
                 size="spi_score", 
                 color="country",
                 hover_name="country",
                 title= "Countries with Better Basic Human Needs", 
                 log_x=True, size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7f87c88b-5105-442b-954d-02ec37c8be4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f87c88b-5105-442b-954d-02ec37c8be4f")) {                    Plotly.newPlot(                        "7f87c88b-5105-442b-954d-02ec37c8be4f",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Norway<br>basic_human_needs=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Norway"],"legendgroup":"Norway","marker":{"color":"#636efa","size":[92.63],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Norway","orientation":"v","showlegend":true,"x":[95.29],"xaxis":"x","y":[92.63],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Finland<br>basic_human_needs=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Finland"],"legendgroup":"Finland","marker":{"color":"#EF553B","size":[92.26],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Finland","orientation":"v","showlegend":true,"x":[95.62],"xaxis":"x","y":[92.26],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Denmark<br>basic_human_needs=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Denmark"],"legendgroup":"Denmark","marker":{"color":"#00cc96","size":[92.15],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Denmark","orientation":"v","showlegend":true,"x":[95.3],"xaxis":"x","y":[92.15],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Iceland<br>basic_human_needs=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Iceland"],"legendgroup":"Iceland","marker":{"color":"#ab63fa","size":[91.78],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Iceland","orientation":"v","showlegend":true,"x":[96.66],"xaxis":"x","y":[91.78],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Switzerland<br>basic_human_needs=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Switzerland"],"legendgroup":"Switzerland","marker":{"color":"#FFA15A","size":[91.78],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Switzerland","orientation":"v","showlegend":true,"x":[95.25],"xaxis":"x","y":[91.78],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Canada<br>basic_human_needs=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Canada"],"legendgroup":"Canada","marker":{"color":"#19d3f3","size":[91.41],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Canada","orientation":"v","showlegend":true,"x":[94.72],"xaxis":"x","y":[91.41],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Sweden<br>basic_human_needs=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Sweden"],"legendgroup":"Sweden","marker":{"color":"#FF6692","size":[91.2],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Sweden","orientation":"v","showlegend":true,"x":[94.5],"xaxis":"x","y":[91.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Netherlands<br>basic_human_needs=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Netherlands"],"legendgroup":"Netherlands","marker":{"color":"#B6E880","size":[90.57],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Netherlands","orientation":"v","showlegend":true,"x":[94.09],"xaxis":"x","y":[90.57],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovert ...

# %% [markdown]
# # **Iceland and Japan are the top 2 countries with better basic human needs facilities.**

# %% [markdown]
# # **Now let’s have a look at the countries with better opportunities:**

# %%
fig = px.scatter(data.query("spi_score >= 85"), 
                 x="opportunity", 
                 y="spi_score",
                 size="spi_score", 
                 color="country",
                 hover_name="country",
                 title= "Countries with Better Opportunities", 
                 log_x=True, size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ac69053e-d547-4a23-a692-3e87fcd57a60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac69053e-d547-4a23-a692-3e87fcd57a60")) {                    Plotly.newPlot(                        "ac69053e-d547-4a23-a692-3e87fcd57a60",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Norway<br>opportunity=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Norway"],"legendgroup":"Norway","marker":{"color":"#636efa","size":[92.63],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Norway","orientation":"v","showlegend":true,"x":[89.3],"xaxis":"x","y":[92.63],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Finland<br>opportunity=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Finland"],"legendgroup":"Finland","marker":{"color":"#EF553B","size":[92.26],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Finland","orientation":"v","showlegend":true,"x":[88.07],"xaxis":"x","y":[92.26],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Denmark<br>opportunity=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Denmark"],"legendgroup":"Denmark","marker":{"color":"#00cc96","size":[92.15],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Denmark","orientation":"v","showlegend":true,"x":[88.41],"xaxis":"x","y":[92.15],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Iceland<br>opportunity=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Iceland"],"legendgroup":"Iceland","marker":{"color":"#ab63fa","size":[91.78],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Iceland","orientation":"v","showlegend":true,"x":[85.04],"xaxis":"x","y":[91.78],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Switzerland<br>opportunity=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Switzerland"],"legendgroup":"Switzerland","marker":{"color":"#FFA15A","size":[91.78],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Switzerland","orientation":"v","showlegend":true,"x":[86.28],"xaxis":"x","y":[91.78],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Canada<br>opportunity=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Canada"],"legendgroup":"Canada","marker":{"color":"#19d3f3","size":[91.41],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Canada","orientation":"v","showlegend":true,"x":[86.68],"xaxis":"x","y":[91.41],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Sweden<br>opportunity=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Sweden"],"legendgroup":"Sweden","marker":{"color":"#FF6692","size":[91.2],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Sweden","orientation":"v","showlegend":true,"x":[87.26],"xaxis":"x","y":[91.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Netherlands<br>opportunity=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Netherlands"],"legendgroup":"Netherlands","marker":{"color":"#B6E880","size":[90.57],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Netherlands","orientation":"v","showlegend":true,"x":[86.38],"xaxis":"x","y":[90.57],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Japan<br>opportunity=%{ ...

# %% [markdown]
# # Norway, Denmark, and Finland are the top 3 countries with better opportunities

# %% [markdown]
# # **Now let’s have a look at the countries with better nutrition and medical care facilities:**

# %%
fig = px.scatter(data.query("spi_score >= 85"), 
                 x="basic_nutri_med_care", 
                 y="spi_score",
                 size="spi_score", 
                 color="country",
                 hover_name="country", 
                 title = "Countries with Better Basic Nutrition & Medical Care",
                 log_x=True, size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9357fb38-da64-4589-874e-7c0d6025e1ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9357fb38-da64-4589-874e-7c0d6025e1ac")) {                    Plotly.newPlot(                        "9357fb38-da64-4589-874e-7c0d6025e1ac",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Norway<br>basic_nutri_med_care=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Norway"],"legendgroup":"Norway","marker":{"color":"#636efa","size":[92.63],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Norway","orientation":"v","showlegend":true,"x":[98.81],"xaxis":"x","y":[92.63],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Finland<br>basic_nutri_med_care=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Finland"],"legendgroup":"Finland","marker":{"color":"#EF553B","size":[92.26],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Finland","orientation":"v","showlegend":true,"x":[98.99],"xaxis":"x","y":[92.26],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Denmark<br>basic_nutri_med_care=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Denmark"],"legendgroup":"Denmark","marker":{"color":"#00cc96","size":[92.15],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Denmark","orientation":"v","showlegend":true,"x":[98.62],"xaxis":"x","y":[92.15],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Iceland<br>basic_nutri_med_care=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Iceland"],"legendgroup":"Iceland","marker":{"color":"#ab63fa","size":[91.78],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Iceland","orientation":"v","showlegend":true,"x":[98.99],"xaxis":"x","y":[91.78],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Switzerland<br>basic_nutri_med_care=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Switzerland"],"legendgroup":"Switzerland","marker":{"color":"#FFA15A","size":[91.78],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Switzerland","orientation":"v","showlegend":true,"x":[98.72],"xaxis":"x","y":[91.78],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Canada<br>basic_nutri_med_care=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Canada"],"legendgroup":"Canada","marker":{"color":"#19d3f3","size":[91.41],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Canada","orientation":"v","showlegend":true,"x":[98.34],"xaxis":"x","y":[91.41],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Sweden<br>basic_nutri_med_care=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Sweden"],"legendgroup":"Sweden","marker":{"color":"#FF6692","size":[91.2],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Sweden","orientation":"v","showlegend":true,"x":[98.9],"xaxis":"x","y":[91.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Netherlands<br>basic_nutri_med_care=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Netherlands"],"legendgroup":"Netherlands","marker":{"color":"#B6E880","size":[90.57],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Netherlands","orientation":"v","showlegend":true,"x":[98.58],"xaxis":"x","y":[90.57],"yaxis":"y","type":"scatter"},{"ho ...

# %% [markdown]
# # **Finland, Iceland, and Norway are the top 3 countries with better nutrition and medical care facilities.**

# %% [markdown]
# # **Now let’s have a look at the countries with better water sanitation:**

# %%
fig = px.scatter(data.query("spi_score >= 85"), 
                 x="water_sanitation", 
                 y="spi_score",
                 size="spi_score", 
                 color="country",
                 hover_name="country", 
                 title = "Countries with Better Water Sanitation",
                 log_x=True, size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9267cf6b-2649-4378-9c06-a33d8ba4a7eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9267cf6b-2649-4378-9c06-a33d8ba4a7eb")) {                    Plotly.newPlot(                        "9267cf6b-2649-4378-9c06-a33d8ba4a7eb",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Norway<br>water_sanitation=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Norway"],"legendgroup":"Norway","marker":{"color":"#636efa","size":[92.63],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Norway","orientation":"v","showlegend":true,"x":[98.33],"xaxis":"x","y":[92.63],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Finland<br>water_sanitation=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Finland"],"legendgroup":"Finland","marker":{"color":"#EF553B","size":[92.26],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Finland","orientation":"v","showlegend":true,"x":[99.26],"xaxis":"x","y":[92.26],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Denmark<br>water_sanitation=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Denmark"],"legendgroup":"Denmark","marker":{"color":"#00cc96","size":[92.15],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Denmark","orientation":"v","showlegend":true,"x":[98.21],"xaxis":"x","y":[92.15],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Iceland<br>water_sanitation=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Iceland"],"legendgroup":"Iceland","marker":{"color":"#ab63fa","size":[91.78],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Iceland","orientation":"v","showlegend":true,"x":[98.82],"xaxis":"x","y":[91.78],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Switzerland<br>water_sanitation=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Switzerland"],"legendgroup":"Switzerland","marker":{"color":"#FFA15A","size":[91.78],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Switzerland","orientation":"v","showlegend":true,"x":[98.96],"xaxis":"x","y":[91.78],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Canada<br>water_sanitation=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Canada"],"legendgroup":"Canada","marker":{"color":"#19d3f3","size":[91.41],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Canada","orientation":"v","showlegend":true,"x":[97.52],"xaxis":"x","y":[91.41],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Sweden<br>water_sanitation=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Sweden"],"legendgroup":"Sweden","marker":{"color":"#FF6692","size":[91.2],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Sweden","orientation":"v","showlegend":true,"x":[98.35],"xaxis":"x","y":[91.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Netherlands<br>water_sanitation=%{x}<br>spi_score=%{marker.size}<extra></extra>","hovertext":["Netherlands"],"legendgroup":"Netherlands","marker":{"color":"#B6E880","size":[90.57],"sizemode":"area","sizeref":0.025730555555555555,"symbol":"circle"},"mode":"markers","name":"Netherlands","orientation":"v","showlegend":true,"x":[98.65],"xaxis":"x","y":[90.57],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</ ...

# %% [markdown]
# # Finland and Switzerland are the top 2 countries with better water sanitation

# %% [markdown]
# # So, this is how we can analyze all the factors considered to calculate the SPI score

# %% [markdown]
# # **Now let’s create a visualization to analyze the overall Social Progress Index scores globally using a choropleth map**

# %%
values = dict(type = 'choropleth', 
           locations = data['country'],
           locationmode = 'country names',
           colorscale='Blues',
           z = data['spi_score'], 
           text = data['country'],
           colorbar = {'title':'Social Progress Index'})

layout = dict(title = 'Social Progress Index', 
              geo = dict(showframe = True, 
                         projection = {'type': 'azimuthal equal area'}))

figure = go.Figure(data = [values], layout=layout)
iplot(figure)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="28501010-8f63-40c6-bece-d52c70a61fe2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28501010-8f63-40c6-bece-d52c70a61fe2")) {                    Plotly.newPlot(                        "28501010-8f63-40c6-bece-d52c70a61fe2",                        [{"colorbar":{"title":{"text":"Social Progress Index"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"locationmode":"country names","locations":["Norway","Finland","Denmark","Iceland","Switzerland","Canada","Sweden","Netherlands","Japan","Germany","Australia","New Zealand","Ireland","Austria","Luxembourg","Belgium","Korea. Republic of","United Kingdom","France","Spain","Estonia","Czechia","Italy","United States","Portugal","Slovenia","Lithuania","Malta","Cyprus","Singapore","Greece","Israel","Slovakia","Latvia","Poland","Croatia","Chile","Costa Rica","Uruguay","Barbados","Argentina","Hungary","Bulgaria","Romania","Mauritius","Trinidad and Tobago","Serbia","Ukraine","Georgia","Kuwait","Malaysia","Panama","Jamaica","Belarus","Armenia","Albania","Montenegro","Tunisia","Ecuador","Moldova","Peru","Russia","Republic of North Macedonia","Kazakhstan","Brazil","Bosnia and Herzegovina","United Arab Emirates","Mexico","Paraguay","Colombia","Thailand","Sri Lanka","Dominican Republic","Maldives","Suriname","Cuba","Cabo Verde","Vietnam","Mongolia","South Africa","Fiji","Kyrgyzstan","Jordan","Bhutan","Oman","Qatar","Turkey","Lebanon","Bolivia","Algeria","Botswana","West Bank and Gaza","Guyana","Indonesia","Uzbekistan","Bahrain","Philippines","Iran","Ghana","China","Morocco","Sao Tome and Principe","El Salvador","Gabon","Saudi Arabia","Namibia","Azerbaijan","Nicaragua","Egypt","Honduras","Senegal","Guatemala","Nepal","Timor-Leste","India","Kenya","Myanmar","Iraq","Libya","Turkmenistan","Bangladesh","Gambia. The","Tajikistan","Malawi","Benin","Tanzania","Comoros","Cambodia","Solomon Islands","Lesotho","C\u00f4te d'Ivoire","Syria","Togo","Zimbabwe","Zambia","Sierra Leone","Rwanda","Nigeria","Cameroon","Uganda","Eswatini","Liberia","Pakistan","Burkina Faso","Laos","Djibouti","Congo. Republic of","Ethiopia","Madagascar","Mozambique","Mali","Mauritania","Angola","Equatorial Guinea","Sudan","Papua New Guinea","Haiti","Guinea-Bissau","Guinea","Burundi","Congo. Democratic Republic of","Niger","Yemen","Somalia","Eritrea","Chad","Central African Republic","South Sudan","World"],"text":["Norway","Finland","Denmark","Iceland","Switzerland","Canada","Sweden","Netherlands","Japan","Germany","Australia","New Zealand","Ireland","Austria","Luxembourg","Belgium","Korea. Republic of","United Kingdom","France","Spain","Estonia","Czechia","Italy","United States","Portugal","Slovenia","Lithuania","Malta","Cyprus","Singapore","Greece","Israel","Slovakia","Latvia","Poland","Croatia","Chile","Costa Rica","Uruguay","Barbados","Argentina","Hungary","Bulgaria","Romania","Mauritius","Trinidad and Tobago","Serbia","Ukraine","Georgia","Kuwait","Malaysia","Panama","Jamaica","Belarus","Armenia","Albania","Montenegro","Tunisia","Ecuador","Moldova","Peru","Russia","Republic of North Macedonia","Kazakhstan","Brazil","Bosnia and Herzegovina","United Arab Emirates","Mexico","Paraguay","Colombia","Thailand","Sri Lanka","Dominican Republic","Maldives","Suriname","Cuba","Cabo Verde","Vietnam","Mongolia","South Africa","Fiji","Kyrgyzstan","Jordan","Bhutan","Oman","Qatar","Turkey","Lebanon","Bolivia","Algeria","Botswana","West Bank and Gaza","Guyana","Indonesia","Uzbekistan","Bahrain","Philippines","Iran","Ghana","China","Morocco","Sao Tome and Principe"," ...

# %% [markdown]
# Summary
#
# The Social Progress Index (SPI) is a measure that gives an understanding of social progress globally. It helps in understanding how much countries care about the overall development of the citizens.
